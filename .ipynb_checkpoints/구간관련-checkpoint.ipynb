# %%
import pandas as pd
import numpy as np
import time
import math

pd.options.mode.chained_assignment = None  # default='warn'

# %%
df_acc = pd.read_csv('acc_highway_name.csv',encoding='utf-8')
df_acc = df_acc.drop('Unnamed: 0',1)
print(len(df_acc))
df_acc.head(1)
# Out:
# 26486
#    Unnamed: 0                 발생시간                         메세지  \
# 0           0  2014-12-01 06:49:02  경인고속도로 부천-신월 3차로 추돌사고 지체 -
#
#                  경도                위도    고속도로  콘존ID
# 0  126.826106822352  37.5225191751392  경인고속도로   NaN

# %%
#df_acc.to_csv('acc_highway_name.csv')

# %%
# 콘존ID - 콘존명 데이터
df_cz_name = pd.read_csv('czid_to_gugan.txt',sep="\t",encoding='CP949')

cols = df_cz_name.columns
cols = cols[0].split(',')

df_cz_name.index = range(len(df_cz_name))
df_cz_name.columns=range(1)

df_cz_name = df_cz_name[0].str.split(',',n=12,expand=True)
df_cz_name.columns = cols
print(len(df_cz_name))
df_cz_name = df_cz_name.drop(['시작노드ID','종료노드ID','차로수','제한속도','버스전용차로유무','도로등급구분코드'],1)
df_cz_name.head(1)
# Out:
# 1438
#          콘존ID    콘존길이 기점종점방향구분코드  노선번호 노선구성순번            콘존명
# 0  0010CZE005  200.00          E  0010      1  경부고속국도시점-구서IC

# %%
# 콘존ID - 좌표 데이터 위도,경도 변환

df_cz_xy = pd.read_csv('acc_conzone.csv',sep=',',encoding='CP949')
df_cz_xy = df_cz_xy.drop('Unnamed: 0',1)
str_arr= ['콘존ID','방향','위도','경도','노선명']
df_cz_xy = df_cz_xy[str_arr]
print(len(df_cz_xy))
df_cz_xy.head(1)
# Out:
# 6301
#          콘존ID 방향         위도          경도  노선명
# 0  0010CZE010  E  35.256977  129.101614  경부선

# %%
# 고속도로 설치 정보 데이터
df_ic = pd.read_csv('highway_sisul.csv',sep=',',encoding="CP949")
df_ic = df_ic.set_index('Unnamed: 0')
print(len(df_ic))
df_ic.head(2)
#df_ic[df_ic['노선명'].str.contains('남해선')].head(1)
# Out:
# 407
#               IC/JCT코드 IC/JCT명         노선명  노선코드        X좌표값       Y좌표값
# Unnamed: 0
# 0           0100I00013    진주IC  남해선(순천-부산)   100  128.118649  35.162711
# 1           0100I00015    진성IC  남해선(순천-부산)   100  128.225744  35.191538

# %%
for s in ['경부','중부','중부내륙','경인','제2경인','영동']:
    print(df_ic[df_ic['노선명']=='%s선'%s].head(1).values[0][2:4])
# Out:
# ['경부선' 10]
# ['중부선' 352]
# ['중부내륙선' 450]
# ['경인선' 1200]
# ['제2경인선' 1100]
# ['영동선' 500]

# %%
#고속도로별 노선코드 빼기

tmp = list(df_acc['고속도로'])
#print(len(tmp))
tmp = set(tmp)

a = pd.DataFrame()

for s in tmp:
    s=s.split('고속')[0]
    
    a=a.append(df_ic[df_ic['노선명']=='%s선'%s].head(1))
a=a.append(df_ic[df_ic['노선명'].str.contains('남해선')].head(1))
tmps = []
for tmp in a['노선코드']:
    tmp = str('%04d'%int(tmp))
    tmps.append(tmp)
a['노선코드'] = tmps
a = pd.merge(a['노선명'],a['노선코드'],on=a.index)
a= a.drop('key_0',1)
a
# Out:
#           노선명  노선코드
# 0         경인선  1200
# 1     서울외곽순환선  1000
# 2        서해안선  0150
# 3         중부선  0352
# 4         호남선  0251
# 5       중부내륙선  0450
# 6         영동선  0500
# 7         경부선  0010
# 8  남해선(순천-부산)  0100

# %%
n_name = list(a['노선명'])
n_code = list(a['노선코드'])

ic_dic = {}

for i in range(len(n_name)):

    tt = []
    tmp = list(df_cz_name['콘존명'][df_cz_name['노선번호']==n_code[i]])
    for t in tmp:
        tt.append(t.split('-')[0])
        tt.append(t.split('-')[1])
    tt=list(set(tt))
    #tt=set(tt) 이거쓰면안댐
    tmp = n_name[i]
    
    if ('남해') in tmp:
        tmp='남해선'
    ic_dic[tmp[:-1]+'고속도로']=tt

ic_dic['남해고속도로'][0]
#이거 순서 맞는지 확인 필요
# Out:
# '군북IC'

# %%
# Out:
# {'경부고속도로',
#  '경인고속도로',
#  '남해고속도로',
#  '대전당진고속도로',
#  '서울외곽순환고속도로',
#  '서해안고속도로',
#  '영동고속도로',
#  '중부고속도로',
#  '중부내륙고속도로',
#  '호남고속도로'}

# %%
df_cz_tmp['시작경도'] = 0.0
df_cz_tmp['시작위도'] = 0.0
df_cz_tmp['끝경도']=0
df_cz_tmp['끝위도']=0

count=0
df_ic['IC/JCT명'] = df_ic['IC/JCT명'].str.upper()
for ic in df_cz_tmp['시작']:
    #m_find = False
    for dfic in df_ic['IC/JCT명']:
        
        if ic in dfic:   
            m_find=True
            xx=df_ic['X좌표값'][df_ic['IC/JCT명']==dfic].copy()
            yy=df_ic['Y좌표값'][df_ic['IC/JCT명']==dfic].copy()

            try:
                xx=float(xx)
                yy=float(yy)
            except:
                xx=xx[xx.index[0]].copy()
                yy=yy[yy.index[0]].copy()
                xx = float(xx)
                yy = float(yy)
            
            df_cz_tmp['시작위도'][df_cz_tmp['시작']==ic] = yy
            df_cz_tmp['시작경도'][df_cz_tmp['시작']==ic] = xx
            count+=1

count=0
df_ic['IC/JCT명'] = df_ic['IC/JCT명'].str.upper()
for ic in df_cz_tmp['끝']:
    #m_find = False
    for dfic in df_ic['IC/JCT명']:
        
        if ic in dfic:   
            m_find=True
            xx=df_ic['X좌표값'][df_ic['IC/JCT명']==dfic].copy()
            yy=df_ic['Y좌표값'][df_ic['IC/JCT명']==dfic].copy()

            try:
                xx=float(xx)
                yy=float(yy)
            except:
                xx=xx.loc[xx.index[0]]
                yy=yy.loc[yy.index[0]]
                xx = float(xx)
                yy = float(yy)
            
            df_cz_tmp['끝위도'][df_cz_tmp['끝']==ic] = yy
            df_cz_tmp['끝경도'][df_cz_tmp['끝']==ic] = xx
            count+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-381c88ef4bee> in <module>
#       1
# ----> 2 df_cz_tmp['시작경도'] = 0.0
#       3 df_cz_tmp['시작위도'] = 0.0
#       4 df_cz_tmp['끝경도']=0
#       5 df_cz_tmp['끝위도']=0
#
# NameError: name 'df_cz_tmp' is not defined

# %%
# Out:
# 70
# 67
#            콘존ID     콘존길이 기점종점방향구분코드  노선번호 노선구성순번            콘존명        시작  \
# 843  0500CZE005   560.00          E  0500      1  영동고속국도시점-서창JC  영동고속국도시점
# 844  0500CZE010  4440.00          E  0500      2      서창JC-월곶JC      서창JC
# 845  0500CZE020  2960.00          E  0500      3      월곶JC-군자JC      월곶JC
# 846  0500CZE025  2080.00          E  0500      4      군자JC-군자TG      군자JC
# 847  0500CZE030  2500.00          E  0500      5     군자TG-서안산IC      군자TG
# 848  0500CZE040  3330.00          E  0500      6     서안산IC-안산IC     서안산IC
# 849  0500CZE050  1230.00          E  0500      7      안산IC-안산JC      안산IC
# 850  0500CZE060  5600.00          E  0500      8      안산JC-둔대JC      안산JC
# 851  0500CZE065  1720.00          E  0500      9      둔대JC-군포IC      둔대JC
# 852  0500CZE070  1390.00          E  0500     10     군포IC-동군포IC      군포IC
# 853  0500CZE080  2150.00          E  0500     11     동군포IC-부곡IC     동군포IC
# 854  0500CZE090  2840.00          E  0500     12     부곡IC-북수원IC      부곡IC
# 855  0500CZE100  6090.00          E  0500     13    북수원IC-동수원IC     북수원IC
# 856  0500CZE110  4900.00          E  0500     14     동수원IC-신갈JC     동수원IC
# 857  0500CZE120  6620.00          E  0500     15      신갈JC-마성IC      신갈JC
#
#          끝        시작경도       시작위도         끝경도        끝위도
# 843   서창JC    0.000000   0.000000  126.739118  37.432337
# 844   월곶JC  126.739118  37.432337    0.000000   0.000000
# 845   군자JC    0.000000   0.000000    0.000000   0.000000
# 846   군자TG    0.000000   0.000000    0.000000   0.000000
# 847  서안산IC    0.000000   0.000000  126.800796  37.349730
# 848   안산IC  126.800796  37.349730  126.849215  37.347671
# 849   안산JC  126.849215  37.347671  126.858377  37.345344
# 850   둔대JC  126.858377  37.345344  126.905945  37.323563
# 851   군포IC  126.905945  37.323563  126.935591  37.329003
# 852  동군포IC  126.935591  37.329003  126.935591  37.329003
# 853   부곡IC  126.935591  37.329003  126.958516  37.326639
# 854  북수원IC  126.958516  37.326639  126.991291  37.320551
# 855  동수원IC  126.991291  37.320551  127.049647  37.299995
# 856   신갈JC  127.049647  37.299995  127.103550  37.290039
# 857   마성IC  127.103550  37.290039  127.185626  37.269124

# %%
#x = 127
#y = 37.5
#x,y = 126.852964704579, 37.3433700997067
## x,y 에서 난 사고에 콘존ID를 붙힐거임
#print(len(df_cz_tmp))


def FindIC(x,y):

    df_x1 = df_cz_tmp['시작경도']
    df_y1 = df_cz_tmp['시작위도']
    d=0
    c=0
    m=0
    mx=0
    for x1 in df_cz_tmp['시작경도']:
        if x1 ==0.0:
            continue
        y1 = df_cz_tmp['시작위도'][df_cz_tmp['시작경도']==x1]
        y1 = y1.values[0]
        a = (x-x1)*(x-x1)
        b = (y-y1)*(y-y1)
        c = a+b
        c = math.sqrt(c)
        if c < d:
            m = c
            mx = x1
        d = c
        #print('%.4f,%.4f'%(x1,y1))
    
    return df_cz_tmp['시작'][df_cz_tmp['시작경도']==mx].values[0]
    
    
#print('거리 ', m)
#print('가장짧은거리의 IC')
#df_cz_tmp['시작'][df_cz_tmp['시작경도']==mx]

# %%
print(FindIC(126.852964704579, 37.3433700997067))
print(FindIC(126.3, 37.3433700997067))
print(FindIC(126.1, 37.3433700997067))
FindIC(126.776906,37.358812)
# Out:
# 안산IC
# 서창JC
# 서창JC
# '서안산IC'

# %%
df_cz_tmp.head(5)
# Out:
#            콘존ID     콘존길이 기점종점방향구분코드  노선번호 노선구성순번            콘존명        시작  \
# 843  0500CZE005   560.00          E  0500      1  영동고속국도시점-서창JC  영동고속국도시점
# 844  0500CZE010  4440.00          E  0500      2      서창JC-월곶JC      서창JC
# 845  0500CZE020  2960.00          E  0500      3      월곶JC-군자JC      월곶JC
# 846  0500CZE025  2080.00          E  0500      4      군자JC-군자TG      군자JC
# 847  0500CZE030  2500.00          E  0500      5     군자TG-서안산IC      군자TG
#
#          끝        시작경도       시작위도         끝경도        끝위도
# 843   서창JC    0.000000   0.000000  126.739118  37.432337
# 844   월곶JC  126.739118  37.432337    0.000000   0.000000
# 845   군자JC    0.000000   0.000000    0.000000   0.000000
# 846   군자TG    0.000000   0.000000    0.000000   0.000000
# 847  서안산IC    0.000000   0.000000  126.800796  37.349730

# %%
df_

# %%
df_ic['X좌표값'][df_ic['IC/JCT명']=='대전IC']
# Out:
# Unnamed: 0
# 86    127.450756
# Name: X좌표값, dtype: float64

# %%
float(df_ic.loc[:]['X좌표값'][df_ic['IC/JCT명']==dfic])
# Out:
# 126.73911799999999

# %%
# Out:
# 126.90594499999999
